# %% [markdown]
# # Comparison
#
# In this notebook, we will:
#
# - Create and Explore our dataset
# - Test our models with the dataset
# - Evaluate them
# - Compare them based on their score & speed

# %% [markdown]
# ### Imports

# %%
from src.lexicon_absa import LexiconABSA
from src.transformer_absa import ML_ABSA
from src.llm_asba import LLMABSA
import pandas as pd
import time
from data_creation import main as create_dataset
from sklearn.metrics import accuracy_score, f1_score, classification_report
import psutil

# %% [markdown]
# ### Create & Explore our dataset
#
# This will generate a dataset file that will be based off random entries from 2 datasets: Laptop_Train_v2 and Restaraunts_Train_v2.
#
# ### Restaraunts_Train_v2(Restaurant reviews):
#
# This dataset consists of over 3K English sentences from the restaurant reviews of Ganu et al. (2009). The original dataset of Ganu et al. included annotations for coarse aspect categories (Subtask 3) and overall sentence polarities...
#
# ### Laptop_Train_v2(Laptop reviews):
#
# This dataset consists of over 3K English sentences extracted from customer reviews of laptops...
#
# More information regarding the dataset: https://www.kaggle.com/datasets/charitarth/semeval-2014-task-4-aspectbasedsentimentanalysis
#
# Credit to the Authors & Organizers of this dataset:
#
# - Ion Androutsopoulos (Athens University of Economics and Business, Greece)
#
# - Dimitris Galanis (“Athena” Research Center, Greece)
#
# - Suresh Manandhar (University of York, UK)
#
# - Harris Papageorgiou (“Athena” Research Center, Greece)
#
# - John Pavlopoulos (Athens University of Economics and Business, Greece)
#
# - Maria Pontiki (“Athena” Research Center, Greece)

# %%
print("Creating dataset...")
create_dataset()

df = pd.read_csv("../data/dataset.csv")
print(f" Loaded dataset with {len(df)} rows")
display(df.head(10))
# Out:
# Creating dataset...
# ✅ dataset.csv created with 30 rows.
#  Loaded dataset with 30 rows
#      id                                           Sentence     Aspect Term  \
# 0     7  Oh great, another update that slows everything...          update
# 1  1970  The steak was excellent and one of the best I ...          butter
# 2     5  The laptop is light and fast but heats up unde...          laptop
# 3  1970  The steak was excellent and one of the best I ...            meat
# 4  2882  The sweet lassi was excellent as was the lamb ...     sweet lassi
# 5  2882  The sweet lassi was excellent as was the lamb ...  lamb chettinad
# 6     8  The waiter was polite, if you consider ignorin...          waiter
# 7     5  The laptop is light and fast but heats up unde...          laptop
# 8  2361  To celebrate a birthday, three of us went to M...            food
# 9  1958  I especially like the keyboard which has chicl...        keyboard
#
#    polarity  from   to
# 0  negative    11   17
# 1  negative    69   75
# 2  positive     4   10
# 3  positive   135  139
# 4  positive     4   15
# 5  positive    41   55
# 6  negative     4   10
# 7  negative    35   41
# 8   neutral    69   73
# 9  positive    22   30

# %% [markdown]
# ### Initialize Models & Create an Evaluation function

# %%
models = [LexiconABSA(), ML_ABSA(), LLMABSA(), LLMABSA("mistral:7b")]
df = df.drop_duplicates(subset=["Sentence", "Aspect Term", "polarity"]).reset_index(drop=True)
unique = df["Sentence"].unique()

def evaluate_model(model, df):
    y_true, y_pred = [], []
    s_time = time.time()
    process = psutil.Process()
    mem_before = process.memory_info().rss / (1024 ** 2)  # MB (Credit goes to gpt for this line)
    print("=" * 100)
    print(f"\n Evaluating Model: {model.name}")
    print("=" * 100)

    for id, text in enumerate(unique):
        preds = model.analyze(text)
        sub_df = df[df["Sentence"] == text]

        print(f"\nSentence {id+1}: {text}")

        for id2, row in sub_df.iterrows():
            gt_aspect = row["Aspect Term"].strip().lower()
            gt_sentiment = row["polarity"].strip().lower()

            matched_pred = None
            for p in preds:
                aspect_text = (p.aspect or "").lower()
                if gt_aspect in aspect_text:
                    matched_pred = p.sentiment
                    break

            y_true.append(gt_sentiment)
            y_pred.append(matched_pred if matched_pred else "notfound")

            print(f"Truth --> Aspect: {gt_aspect} | Sentiment: {gt_sentiment}")

        if preds:
            for p in preds:
                print(f"Predicted --> Aspect: {p.aspect} | Sentiment: {p.sentiment} | Confidence: {p.confidence:.2f}")
        else:
            print("Predicted --> No aspects found")


    elapsed = time.time() - s_time
    mem_after = process.memory_info().rss / (1024 ** 2)
    mem_used = mem_after - mem_before
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)
    print(f" \n Accuracy: {acc:.3f} | F1: {f1:.3f} | Time: {elapsed:.2f}s | Memory: {mem_used:.2f} MB")
    print("\n Classification Report:")
    print(classification_report(y_true, y_pred, digits=3, zero_division=0))
    return acc, f1, elapsed, mem_used
# Out:
# C:\Users\bebef\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\convert_slow_tokenizer.py:564: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %% [markdown]
# ### Start Testing

# %%
results = []
for model in models:
    acc, f1, t, memused = evaluate_model(model, df)
    results.append({
        "Model": model.name,
        "Accuracy": acc,
        "F1": f1,
        "Time (s)": t,
        "Memory (MB)": memused
    })

results_df = pd.DataFrame(results)
display(results_df)
# Out:
# ====================================================================================================
#
#  Evaluating Model: LexiconABSA
# ====================================================================================================
#
# Sentence 1: Oh great, another update that slows everything down.
# Truth --> Aspect: update | Sentiment: negative
# Predicted --> No aspects found
#
# Sentence 2: The steak was excellent and one of the best I have had (I tasted the butter intitally but in no way did it overwhelm the flavor of the meat).
# Truth --> Aspect: butter | Sentiment: negative
# Truth --> Aspect: meat | Sentiment: positive
# Truth --> Aspect: flavor | Sentiment: neutral
# Truth --> Aspect: steak | Sentiment: positive
# Predicted --> Aspect: steak | Sentiment: positive | Confidence: 0.57
#
# Sentence 3: The laptop is light and fast but heats up under load.
# Truth --> Aspect: laptop | Sentiment: positive
# Truth --> Aspect: laptop | Sentiment: negative
# Predicted --> Aspect: laptop | Sentiment: neutral | Confidence: 0.00
#
# Sentence 4: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# Truth --> Aspect: sweet lassi | Sentiment: positive
# Truth --> Aspect: lamb chettinad | Sentiment: positive
# Truth --> Aspect: rasamalai | Sentiment: negative
# Truth --> Aspect: garlic naan | Sentiment: positive
# Predicted --> Aspect: lassi | Sentiment: positive | Confidence: 0.46
# Predicted --> Aspect: rasamalai | Sentiment: neutral | Confidence: 0.00
#
# Sentence 5: The waiter was polite, if you consider ignoring us polite.
# Truth --> Aspect: waiter | Sentiment: negative
# Predicted --> Aspect: waiter | Sentiment: neutral | Confidence: 0.00
#
# Sentence 6: To celebrate a birthday, three of us went to Mare anticipating great food.
# Truth --> Aspect: food | Sentiment: neutral
# Predicted --> Aspect: food | Sentiment: neutral | Confidence: 0.00
#
# Sentence 7: I especially like the keyboard which has chiclet type keys.
# Truth --> Aspect: keyboard | Sentiment: positive
# Truth --> Aspect: keys | Sentiment: positive
# Predicted --> No aspects found
#
# Sentence 8: It was hard to handle and operate at school.
# Truth --> Aspect: handle | Sentiment: negative
# Truth --> Aspect: operate | Sentiment: negative
# Predicted --> No aspects found
#
# Sentence 9: Bagels are ok, but be sure not to make any special requests!
# Truth --> Aspect: bagels | Sentiment: neutral
# Predicted --> Aspect: Bagels | Sentiment: positive | Confidence: 0.30
# Predicted --> Aspect: requests | Sentiment: neutral | Confidence: 0.00
#
# Sentence 10: The phone screen is bright, but the battery drains quickly.
# Truth --> Aspect: battery | Sentiment: negative
# Truth --> Aspect: screen | Sentiment: positive
# Predicted --> Aspect: screen | Sentiment: positive | Confidence: 0.44
#
# Sentence 11: The laptop was very easy to set up.
# Truth --> Aspect: set up | Sentiment: positive
# Predicted --> Aspect: laptop | Sentiment: positive | Confidence: 0.44
#
# Sentence 12: The wifi was slow, but at least it was free.
# Truth --> Aspect: wifi | Sentiment: negative
# Truth --> Aspect: wifi | Sentiment: positive
# Predicted --> Aspect: wifi | Sentiment: neutral | Confidence: 0.00
#
# Sentence 13: As well as having the plug in the computer come loose.
# Truth --> Aspect: plug | Sentiment: negative
# Predicted --> No aspects found
#
# Sentence 14: The pizza was delicious.
# Truth --> Aspect: pizza | Sentiment: positive
# Predicted --> Aspect: pizza | Sentiment: positive | Confidence: 0.57
#
# Sentence 15: This phone could be worse, I guess that's something.
# Truth --> Aspect: phone | Sentiment: neutral
# Predicted --> Aspect: phone | Sentiment: negative | Confidence: 0.48
#
# Sentence 16: The hotel room was clean.
# Truth --> Aspect: room | Sentiment: positive
# Predicted --> Aspect: room | Sentiment: positive | Confidence: 0.40
#
# Sentence 17: While the menu isn't especially groundbreaking, everything I've tried so far has been well-executed and tasty.
# Truth --> Aspect: menu | Sentiment: conflict
# Predicted --> No aspects found
#
# Sentence 18: The battery life is terrible.
# Truth --> Aspect: battery life | Sentiment: negative
# Predicted --> Aspect: life | Sentiment: negative | Confidence: 0.48
#
# Sentence 19: My husband got me this for Chrismas after getting me a very expensve laptop that did not work after 2 days.
# Truth --> Aspect: work | Sentiment: negative
# Predicted --> Aspect: laptop | Sentiment: neutral | Confidence: 0.00
#
#  Accuracy: 0.167 | F1: 0.125 | Time: 0.22s | Memory: 1.01 MB
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#     conflict      0.000     0.000     0.000         1
#     negative      0.000     0.000     0.000        12
#      neutral      0.143     0.250     0.182         4
#     notfound      0.000     0.000     0.000         0
#     positive      0.800     0.308     0.444        13
#
#     accuracy                          0.167        30
#    macro avg      0.189     0.112     0.125        30
# weighted avg      0.366     0.167     0.217        30
#
# ====================================================================================================
#
#  Evaluating Model: ML_ABSA
# ====================================================================================================
#
# Sentence 1: Oh great, another update that slows everything down.
# Truth --> Aspect: update | Sentiment: negative
# Predicted --> Aspect: Oh great, another update | Sentiment: negative | Confidence: 0.75
#
# Sentence 2: The steak was excellent and one of the best I have had (I tasted the butter intitally but in no way did it overwhelm the flavor of the meat).
# Truth --> Aspect: butter | Sentiment: negative
# Truth --> Aspect: meat | Sentiment: positive
# Truth --> Aspect: flavor | Sentiment: neutral
# Truth --> Aspect: steak | Sentiment: positive
# Predicted --> Aspect: The steak | Sentiment: positive | Confidence: 1.00
# Predicted --> Aspect: the butter | Sentiment: negative | Confidence: 0.80
# Predicted --> Aspect: no way | Sentiment: positive | Confidence: 0.75
# Predicted --> Aspect: the flavor | Sentiment: neutral | Confidence: 0.64
# Predicted --> Aspect: the meat | Sentiment: neutral | Confidence: 0.54
#
# Sentence 3: The laptop is light and fast but heats up under load.
# Truth --> Aspect: laptop | Sentiment: positive
# Truth --> Aspect: laptop | Sentiment: negative
# Predicted --> Aspect: The laptop | Sentiment: positive | Confidence: 0.98
# Predicted --> Aspect: load | Sentiment: negative | Confidence: 1.00
#
# Sentence 4: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# Truth --> Aspect: sweet lassi | Sentiment: positive
# Truth --> Aspect: lamb chettinad | Sentiment: positive
# Truth --> Aspect: rasamalai | Sentiment: negative
# Truth --> Aspect: garlic naan | Sentiment: positive
# Predicted --> Aspect: The sweet lassi | Sentiment: positive | Confidence: 1.00
# Predicted --> Aspect: the lamb chettinad | Sentiment: positive | Confidence: 1.00
# Predicted --> Aspect: the garlic naan | Sentiment: positive | Confidence: 0.97
# Predicted --> Aspect: the rasamalai | Sentiment: negative | Confidence: 0.99
#
# Sentence 5: The waiter was polite, if you consider ignoring us polite.
# Truth --> Aspect: waiter | Sentiment: negative
# Predicted --> Aspect: The waiter | Sentiment: positive | Confidence: 0.99
#
# Sentence 6: To celebrate a birthday, three of us went to Mare anticipating great food.
# Truth --> Aspect: food | Sentiment: neutral
# Predicted --> Aspect: a birthday | Sentiment: neutral | Confidence: 0.99
# Predicted --> Aspect: Mare | Sentiment: neutral | Confidence: 0.99
# Predicted --> Aspect: great food | Sentiment: neutral | Confidence: 0.86
#
# Sentence 7: I especially like the keyboard which has chiclet type keys.
# Truth --> Aspect: keyboard | Sentiment: positive
# Truth --> Aspect: keys | Sentiment: positive
# Predicted --> Aspect: the keyboard | Sentiment: positive | Confidence: 0.99
# Predicted --> Aspect: chiclet type keys | Sentiment: positive | Confidence: 0.99
#
# Sentence 8: It was hard to handle and operate at school.
# Truth --> Aspect: handle | Sentiment: negative
# Truth --> Aspect: operate | Sentiment: negative
# Predicted --> Aspect: school | Sentiment: negative | Confidence: 0.93
#
# Sentence 9: Bagels are ok, but be sure not to make any special requests!
# Truth --> Aspect: bagels | Sentiment: neutral
# Predicted --> Aspect: Bagels | Sentiment: neutral | Confidence: 0.49
# Predicted --> Aspect: any special requests | Sentiment: negative | Confidence: 0.94
#
# Sentence 10: The phone screen is bright, but the battery drains quickly.
# Truth --> Aspect: battery | Sentiment: negative
# Truth --> Aspect: screen | Sentiment: positive
# Predicted --> Aspect: The phone screen | Sentiment: positive | Confidence: 1.00
# Predicted --> Aspect: the battery | Sentiment: negative | Confidence: 0.99
#
# Sentence 11: The laptop was very easy to set up.
# Truth --> Aspect: set up | Sentiment: positive
# Predicted --> Aspect: The laptop | Sentiment: positive | Confidence: 1.00
#
# Sentence 12: The wifi was slow, but at least it was free.
# Truth --> Aspect: wifi | Sentiment: negative
# Truth --> Aspect: wifi | Sentiment: positive
# Predicted --> Aspect: The wifi | Sentiment: negative | Confidence: 1.00
#
# Sentence 13: As well as having the plug in the computer come loose.
# Truth --> Aspect: plug | Sentiment: negative
# Predicted --> Aspect: the plug | Sentiment: negative | Confidence: 1.00
# Predicted --> Aspect: the computer | Sentiment: negative | Confidence: 0.87
#
# Sentence 14: The pizza was delicious.
# Truth --> Aspect: pizza | Sentiment: positive
# Predicted --> Aspect: The pizza | Sentiment: positive | Confidence: 0.99
#
# Sentence 15: This phone could be worse, I guess that's something.
# Truth --> Aspect: phone | Sentiment: neutral
# Predicted --> Aspect: This phone | Sentiment: negative | Confidence: 0.95
#
# Sentence 16: The hotel room was clean.
# Truth --> Aspect: room | Sentiment: positive
# Predicted --> Aspect: The hotel room | Sentiment: positive | Confidence: 0.99
#
# Sentence 17: While the menu isn't especially groundbreaking, everything I've tried so far has been well-executed and tasty.
# Truth --> Aspect: menu | Sentiment: conflict
# Predicted --> Aspect: the menu | Sentiment: negative | Confidence: 0.77
#
# Sentence 18: The battery life is terrible.
# Truth --> Aspect: battery life | Sentiment: negative
# Predicted --> Aspect: The battery life | Sentiment: negative | Confidence: 0.99
#
# Sentence 19: My husband got me this for Chrismas after getting me a very expensve laptop that did not work after 2 days.
# Truth --> Aspect: work | Sentiment: negative
# Predicted --> Aspect: My husband | Sentiment: neutral | Confidence: 0.81
# Predicted --> Aspect: Chrismas | Sentiment: neutral | Confidence: 1.00
# Predicted --> Aspect: a very expensve laptop | Sentiment: negative | Confidence: 1.00
# Predicted --> Aspect: 2 days | Sentiment: negative | Confidence: 1.00
#
#  Accuracy: 0.667 | F1: 0.437 | Time: 5.09s | Memory: 328.09 MB
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#     conflict      0.000     0.000     0.000         1
#     negative      0.700     0.583     0.636        12
#      neutral      0.750     0.750     0.750         4
#     notfound      0.000     0.000     0.000         0
#     positive      0.833     0.769     0.800        13
#
#     accuracy                          0.667        30
#    macro avg      0.457     0.421     0.437        30
# weighted avg      0.741     0.667     0.701        30
#
# ====================================================================================================
#
#  Evaluating Model: LLMABSA (phi3)
# ====================================================================================================
#
# Sentence 1: Oh great, another update that slows everything down.
# Truth --> Aspect: update | Sentiment: negative
# Predicted --> Aspect: update | Sentiment: negative | Confidence: 0.95
# Predicted --> Aspect: everything slows down | Sentiment: negative | Confidence: 0.98
#
# Sentence 2: The steak was excellent and one of the best I have had (I tasted the butter intitally but in no way did it overwhelm the flavor of the meat).
# Truth --> Aspect: butter | Sentiment: negative
# Truth --> Aspect: meat | Sentiment: positive
# Truth --> Aspect: flavor | Sentiment: neutral
# Truth --> Aspect: steak | Sentiment: positive
# Predicted --> Aspect: steak | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: butter taste | Sentiment: neutral | Confidence: 0.80
#
# Sentence 3: The laptop is light and fast but heats up under load.
# Truth --> Aspect: laptop | Sentiment: positive
# Truth --> Aspect: laptop | Sentiment: negative
# Predicted --> Aspect: laptop weight | Sentiment: positive | Confidence: 0.87
# Predicted --> Aspect: laptop speed | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: device overheating under load | Sentiment: negative | Confidence: 0.97
#
# Sentence 4: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# Truth --> Aspect: sweet lassi | Sentiment: positive
# Truth --> Aspect: lamb chettinad | Sentiment: positive
# Truth --> Aspect: rasamalai | Sentiment: negative
# Truth --> Aspect: garlic naan | Sentiment: positive
# Predicted --> Aspect: sweet lassi | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: lamb chettinad | Sentiment: positive | Confidence: 0.97
# Predicted --> Aspect: garlic naan | Sentiment: positive | Confidence: 0.98
# Predicted --> Aspect: rasamalai | Sentiment: negative | Confidence: 0.96
#
# Sentence 5: The waiter was polite, if you consider ignoring us polite.
# Truth --> Aspect: waiter | Sentiment: negative
# Predicted --> Aspect: waiter | Sentiment: positive | Confidence: 0.10
# Predicted --> Aspect: ignoring us | Sentiment: negative | Confidence: 0.87
#
# Sentence 6: To celebrate a birthday, three of us went to Mare anticipating great food.
# Truth --> Aspect: food | Sentiment: neutral
# Predicted --> Aspect: celebration | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: Mare anticipating great food | Sentiment: neutral to positive due to sarcasm detection as implied negative tone towards mare's actual reputation for serving poor quality food. | Confidence: 0.98
#
# Sentence 7: I especially like the keyboard which has chiclet type keys.
# Truth --> Aspect: keyboard | Sentiment: positive
# Truth --> Aspect: keys | Sentiment: positive
# Predicted --> Aspect: keyboard | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: chiclet type keys | Sentiment: neutral | Confidence: 0.80
#
# Sentence 8: It was hard to handle and operate at school.
# Truth --> Aspect: handle | Sentiment: negative
# Truth --> Aspect: operate | Sentiment: negative
# Predicted --> Aspect: hardness | Sentiment: negative | Confidence: 0.95
# Predicted --> Aspect: handleability and operation at school | Sentiment: negative | Confidence: 0.97
#
# Sentence 9: Bagels are ok, but be sure not to make any special requests!
# Truth --> Aspect: bagels | Sentiment: neutral
# Predicted --> Aspect: bagels | Sentiment: neutral | Confidence: 0.65
# Predicted --> Aspect: special requests | Sentiment: negative | Confidence: 0.95
#
# Sentence 10: The phone screen is bright, but the battery drains quickly.
# Truth --> Aspect: battery | Sentiment: negative
# Truth --> Aspect: screen | Sentiment: positive
# Predicted --> Aspect: phone screen | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: battery | Sentiment: negative | Confidence: 0.98
#
# Sentence 11: The laptop was very easy to set up.
# Truth --> Aspect: set up | Sentiment: positive
# Predicted --> Aspect: laptop setup | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: ease of set up | Sentiment: positive | Confidence: 0.98
#
# Sentence 12: The wifi was slow, but at least it was free.
# Truth --> Aspect: wifi | Sentiment: negative
# Truth --> Aspect: wifi | Sentiment: positive
# Predicted --> Aspect: wifi speed | Sentiment: negative | Confidence: 0.95
# Predicted --> Aspect: wifi cost | Sentiment: positive | Confidence: 0.98
#
# Sentence 13: As well as having the plug in the computer come loose.
# Truth --> Aspect: plug | Sentiment: negative
# Predicted --> Aspect: plug | Sentiment: negative | Confidence: 0.80
# Predicted --> Aspect: computer power supply stability | Sentiment: negative | Confidence: 0.90
#
# Sentence 14: The pizza was delicious.
# Truth --> Aspect: pizza | Sentiment: positive
# Predicted --> Aspect: pizza | Sentiment: positive | Confidence: 1.00
# Predicted --> Aspect: flavor | Sentiment: positive | Confidence: 0.95
#
# Sentence 15: This phone could be worse, I guess that's something.
# Truth --> Aspect: phone | Sentiment: neutral
# Predicted --> Aspect: phone | Sentiment: neutral | Confidence: 0.65
# Predicted --> Aspect: quality | Sentiment: negative | Confidence: 0.87
#
# Sentence 16: The hotel room was clean.
# Truth --> Aspect: room | Sentiment: positive
# Predicted --> Aspect: hotel room | Sentiment: positive | Confidence: 0.90
# Predicted --> Aspect: cleanliness of the hotel room | Sentiment: neutral | Confidence: 0.86
#
# Sentence 17: While the menu isn't especially groundbreaking, everything I've tried so far has been well-executed and tasty.
# Truth --> Aspect: menu | Sentiment: conflict
# Predicted --> Aspect: menu | Sentiment: neutral | Confidence: 0.70
# Predicted --> Aspect: execution of dishes | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: taste of food | Sentiment: positive | Confidence: 0.92
#
# Sentence 18: The battery life is terrible.
# Truth --> Aspect: battery life | Sentiment: negative
# Predicted --> Aspect: battery life | Sentiment: negative | Confidence: 0.95
#
# Sentence 19: My husband got me this for Chrismas after getting me a very expensve laptop that did not work after 2 days.
# Truth --> Aspect: work | Sentiment: negative
# Predicted --> Aspect: husband's gift | Sentiment: negative | Confidence: 0.90
# Predicted --> Aspect: Christmas present | Sentiment: neutral | Confidence: 0.80
#
#  Accuracy: 0.633 | F1: 0.324 | Time: 72.79s | Memory: -6.42 MB
#
#  Classification Report:
#                                                                                                                                        precision    recall  f1-score   support
#
#                                                                                                                              conflict      0.000     0.000     0.000         1
#                                                                                                                              negative      0.875     0.583     0.700        12
#                                                                                                                               neutral      0.400     0.500     0.444         4
# neutral to positive due to sarcasm detection as implied negative tone towards mare's actual reputation for serving poor quality food.      0.000     0.000     0.000         0
#                                                                                                                              notfound      0.000     0.000     0.000         0
#                                                                                                                              positive      0.833     0.769     0.800        13
#
#                                                                                                                              accuracy                          0.633        30
#                                                                                                                             macro avg      0.351     0.309     0.324        30
#                                                                                                                          weighted avg      0.764     0.633     0.686        30
#
# ====================================================================================================
#
#  Evaluating Model: LLMABSA (mistral:7b)
# ====================================================================================================
#
# Sentence 1: Oh great, another update that slows everything down.
# Truth --> Aspect: update | Sentiment: negative
# Predicted --> Aspect: update | Sentiment: negative | Confidence: 0.95
# Predicted --> Aspect: speed | Sentiment: negative | Confidence: 0.80
#
# Sentence 2: The steak was excellent and one of the best I have had (I tasted the butter intitally but in no way did it overwhelm the flavor of the meat).
# Truth --> Aspect: butter | Sentiment: negative
# Truth --> Aspect: meat | Sentiment: positive
# Truth --> Aspect: flavor | Sentiment: neutral
# Truth --> Aspect: steak | Sentiment: positive
# Predicted --> Aspect: steak | Sentiment: positive | Confidence: 0.90
# Predicted --> Aspect: taste | Sentiment: neutral | Confidence: 0.75
# Predicted --> Aspect: butter | Sentiment: negative | Confidence: 0.80
# Predicted --> Aspect: flavor of the meat | Sentiment: positive | Confidence: 0.90
#
# Sentence 3: The laptop is light and fast but heats up under load.
# Truth --> Aspect: laptop | Sentiment: positive
# Truth --> Aspect: laptop | Sentiment: negative
# Predicted --> Aspect: laptop weight | Sentiment: positive | Confidence: 0.85
# Predicted --> Aspect: laptop speed | Sentiment: positive | Confidence: 0.90
# Predicted --> Aspect: laptop under load | Sentiment: negative | Confidence: 0.95
#
# Sentence 4: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# Truth --> Aspect: sweet lassi | Sentiment: positive
# Truth --> Aspect: lamb chettinad | Sentiment: positive
# Truth --> Aspect: rasamalai | Sentiment: negative
# Truth --> Aspect: garlic naan | Sentiment: positive
# Predicted --> Aspect: sweet lassi | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: lamb chettinad | Sentiment: positive | Confidence: 0.90
# Predicted --> Aspect: garlic naan | Sentiment: positive | Confidence: 0.85
# Predicted --> Aspect: rasamalai | Sentiment: negative | Confidence: 0.90
#
# Sentence 5: The waiter was polite, if you consider ignoring us polite.
# Truth --> Aspect: waiter | Sentiment: negative
# Predicted --> Aspect: waiter | Sentiment: neutral | Confidence: 0.65
# Predicted --> Aspect: polite (sarcasm) | Sentiment: negative | Confidence: 0.90
# Predicted --> Aspect: ignoring us | Sentiment: negative | Confidence: 0.75
#
# Sentence 6: To celebrate a birthday, three of us went to Mare anticipating great food.
# Truth --> Aspect: food | Sentiment: neutral
# Predicted --> Aspect: birthday | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: three of us | Sentiment: neutral | Confidence: 0.75
# Predicted --> Aspect: Mare | Sentiment: neutral | Confidence: 0.80
# Predicted --> Aspect: anticipating | Sentiment: positive | Confidence: 0.90
# Predicted --> Aspect: great food | Sentiment: neutral | Confidence: 0.65
#
# Sentence 7: I especially like the keyboard which has chiclet type keys.
# Truth --> Aspect: keyboard | Sentiment: positive
# Truth --> Aspect: keys | Sentiment: positive
# Predicted --> Aspect: keyboard | Sentiment: positive | Confidence: 0.95
# Predicted --> Aspect: chiclet type keys | Sentiment: positive | Confidence: 0.88
#
# Sentence 8: It was hard to handle and operate at school.
# Truth --> Aspect: handle | Sentiment: negative
# Truth --> Aspect: operate | Sentiment: negative
# Predicted --> Aspect: handling | Sentiment: negative | Confidence: 0.90
# Predicted --> Aspect: operation | Sentiment: negative | Confidence: 0.90
#
# Sentence 9: Bagels are ok, but be sure not to make any special requests!
# Truth --> Aspect: bagels | Sentiment: neutral
# Predicted --> Aspect: bagels | Sentiment: neutral | Confidence: 0.75
# Predicted --> Aspect: special requests | Sentiment: negative | Confidence: 0.80
#
# Sentence 10: The phone screen is bright, but the battery drains quickly.
# Truth --> Aspect: battery | Sentiment: negative
# Truth --> Aspect: screen | Sentiment: positive
# Predicted --> Aspect: phone screen | Sentiment: positive | Confidence: 0.85
# Predicted --> Aspect: battery | Sentiment: negative | Confidence: 0.90
#
# Sentence 11: The laptop was very easy to set up.
# Truth --> Aspect: set up | Sentiment: positive
# Predicted --> Aspect: laptop setup | Sentiment: positive | Confidence: 0.95
#
# Sentence 12: The wifi was slow, but at least it was free.
# Truth --> Aspect: wifi | Sentiment: negative
# Truth --> Aspect: wifi | Sentiment: positive
# Predicted --> Aspect: wifi speed | Sentiment: negative | Confidence: 0.95
# Predicted --> Aspect: wifi cost | Sentiment: positive | Confidence: 0.85
#
# Sentence 13: As well as having the plug in the computer come loose.
# Truth --> Aspect: plug | Sentiment: negative
# Predicted --> Aspect: plug | Sentiment: negative | Confidence: 0.80
#
# Sentence 14: The pizza was delicious.
# Truth --> Aspect: pizza | Sentiment: positive
# Predicted --> Aspect: pizza | Sentiment: positive | Confidence: 0.95
#
# Sentence 15: This phone could be worse, I guess that's something.
# Truth --> Aspect: phone | Sentiment: neutral
# Predicted --> Aspect: phone | Sentiment: neutral | Confidence: 0.85
# Predicted --> Aspect: could be worse | Sentiment: neutral | Confidence: 0.90
# Predicted --> Aspect: I guess | Sentiment: neutral | Confidence: 0.80
#
# Sentence 16: The hotel room was clean.
# Truth --> Aspect: room | Sentiment: positive
# Predicted --> Aspect: hotel room | Sentiment: positive | Confidence: 0.90
#
# Sentence 17: While the menu isn't especially groundbreaking, everything I've tried so far has been well-executed and tasty.
# Truth --> Aspect: menu | Sentiment: conflict
# Predicted --> Aspect: menu | Sentiment: negative | Confidence: 0.75
# Predicted --> Aspect: well-executed dishes | Sentiment: positive | Confidence: 0.90
#
# Sentence 18: The battery life is terrible.
# Truth --> Aspect: battery life | Sentiment: negative
# Predicted --> Aspect: battery life | Sentiment: negative | Confidence: 1.00
#
# Sentence 19: My husband got me this for Chrismas after getting me a very expensve laptop that did not work after 2 days.
# Truth --> Aspect: work | Sentiment: negative
# Predicted --> Aspect: husband | Sentiment: neutral | Confidence: 0.50
# Predicted --> Aspect: Christmas gift | Sentiment: positive | Confidence: 0.75
# Predicted --> Aspect: expensive laptop | Sentiment: negative | Confidence: 0.90
# Predicted --> Aspect: laptop performance | Sentiment: negative | Confidence: 0.85
#
#  Accuracy: 0.700 | F1: 0.453 | Time: 202.54s | Memory: -105.41 MB
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#     conflict      0.000     0.000     0.000         1
#     negative      0.778     0.583     0.667        12
#      neutral      0.750     0.750     0.750         4
#     notfound      0.000     0.000     0.000         0
#     positive      0.846     0.846     0.846        13
#
#     accuracy                          0.700        30
#    macro avg      0.475     0.436     0.453        30
# weighted avg      0.778     0.700     0.733        30
#                   Model  Accuracy        F1    Time (s)  Memory (MB)
# 0           LexiconABSA  0.166667  0.125253    0.219970     1.007812
# 1               ML_ABSA  0.666667  0.437273    5.090733   328.085938
# 2        LLMABSA (phi3)  0.633333  0.324074   72.791583    -6.417969
# 3  LLMABSA (mistral:7b)  0.700000  0.452564  202.543202  -105.414062

# %% [markdown]
# ### Print Summary

# %%
print("Final Comparison")
display(results_df.sort_values(by="F1", ascending=False))
# Out:
# Final Comparison
#                   Model  Accuracy        F1    Time (s)  Memory (MB)
# 3  LLMABSA (mistral:7b)  0.700000  0.452564  202.543202  -105.414062
# 1               ML_ABSA  0.666667  0.437273    5.090733   328.085938
# 2        LLMABSA (phi3)  0.633333  0.324074   72.791583    -6.417969
# 0           LexiconABSA  0.166667  0.125253    0.219970     1.007812
